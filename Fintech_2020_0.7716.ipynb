# %%
import pandas as pd
import numpy as np
import scipy 
import scipy.stats
import matplotlib.pyplot as plt
import datetime
import time
import sklearn
from sklearn import metrics,ensemble
from sklearn.model_selection import KFold,train_test_split,cross_val_score,GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.feature_selection import SelectFromModel
import lightgbm as lgb
from numpy import sort
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## trd 预处理

# %%
def trd_add(get_path,store_path):
    data_trd = pd.read_csv(get_path)
    week_day_dict = {0: '0',1: '0',2: '0',3: '0',4: '1',5: '1',6: '1'}
    data_trd['weekday'] = data_trd['trx_tm'].apply(lambda x: week_day_dict[datetime.datetime.strptime(x, "%Y-%m-%d %H:%M:%S").weekday()])
    data_trd['day_time'] = data_trd['trx_tm'].apply(lambda x: x[11:13])
    data_trd['day_time'] = data_trd['day_time'].apply(lambda x: 0 if int(x)>=7 and int(x)<=17 else 1)
    
    if 'flag' in data_trd.keys():
        data_trd.drop('flag',axis=1,inplace=True)
    
    column_set = ['Dat_Flg1_Cd','Dat_Flg3_Cd','Trx_Cod1_Cd','Trx_Cod2_Cd','weekday','day_time']
    for i in column_set:
        subset = pd.get_dummies(data_trd[i])
        subset.columns = [i+'_'+str(jj) for jj in subset.keys()]
        data_trd =pd.concat([data_trd,subset],axis = 1)
    data_trd.drop(['Dat_Flg1_Cd','Dat_Flg3_Cd','Trx_Cod1_Cd','Trx_Cod2_Cd','trx_tm','weekday','day_time'],axis=1,inplace=True)
   
    key_set= data_trd.keys()[2:]
    all_trd = data_trd.groupby(['id']).\
                            agg({'cny_trx_amt':{'sum','max','min','std','mean'}})
    for i in key_set:
        subdata = data_trd.groupby(['id']).agg({i:'sum'})
        all_trd = pd.concat([all_trd,subdata],axis=1)
    all_trd.to_csv(store_path)

# %%
trd_add('train/trd.csv','train/all_trd.csv')
trd_add('b/trd_b.csv','b/all_trd_b.csv')

# %%
all_trd = pd.read_csv('train/all_trd.csv')
all_trd_1 = pd.read_csv('b/all_trd_b.csv')
all_trd.drop('Trx_Cod2_Cd_211',axis=1,inplace=True)
all_trd_1.drop('Trx_Cod2_Cd_124',axis=1,inplace=True)
all_trd.to_csv('train/all_trd.csv',index=False)
all_trd_1.to_csv('b/all_trd_b.csv',index=False)
print(all_trd.shape,all_trd_1.shape)
# Out:
# (31993, 73) (3190, 73)

# %% [markdown]
# ## tag 预处理

# %%
def tag_add(get_path,store_path):
    data_tag = pd.read_csv(get_path)
    column_set1 = ['gdr_cd','mrg_situ_cd','edu_deg_cd','acdm_deg_cd','deg_cd']
    column_set2 = ['fin_rsk_ases_grd_cd','confirm_rsk_ases_lvl_typ_cd',\
          'cust_inv_rsk_endu_lvl_cd','l6mon_daim_aum_cd','tot_ast_lvl_cd',\
          'pot_ast_lvl_cd','bk1_cur_year_mon_avg_agn_amt_cd','pl_crd_lmt_cd',\
          'hld_crd_card_grd_cd','l1y_crd_card_csm_amt_dlm_cd','perm_crd_lmt_cd',\
          'cur_debit_crd_lvl']
    for i in column_set1:
        subset = pd.get_dummies(data_tag[i])
        subset.columns = [i+'_'+str(jj) for jj in subset.keys()]
        data_tag =pd.concat([data_tag,subset],axis = 1)
        data_tag.drop(i,axis=1,inplace=True)
    for i in column_set2:
        subset = pd.get_dummies(data_tag[i])
        subset.columns = [i+'_'+str(jj) for jj in subset.keys()]
        data_tag =pd.concat([data_tag,subset],axis = 1)
    for i in data_tag.keys()[1:]:
        data_tag.loc[data_tag[i]=='\\N',i]=np.nan
        data_tag[i] = data_tag[i].astype("float")
        
    subsub_split= pd.DataFrame()
    for i in ['age','job_year','cur_debit_min_opn_dt_cnt','cur_credit_min_opn_dt_cnt']:
        sub_split = pd.qcut(data_tag[i],5,labels=False,duplicates='drop')
        sub_split.columns = [i+"_split"]
        subsub_split =pd.concat([subsub_split,sub_split],axis = 1)
    subsub_split.columns = [i+"_split" for i in subsub_split.columns]
    data_tag =pd.concat([data_tag,subsub_split],axis = 1)
    data_tag.to_csv(store_path,index=False)

# %%
tag_add('train/tag.csv','train/all_tag.csv')
tag_add('b/tag_b.csv','b/all_tag_b.csv')

# %%
all_tag = pd.read_csv('train/all_tag.csv')
all_tag_1 = pd.read_csv('b/all_tag_b.csv')
all_tag_1.drop('fin_rsk_ases_grd_cd_10',axis=1,inplace=True)
all_tag.drop(['edu_deg_cd_J','fin_rsk_ases_grd_cd_11','fin_rsk_ases_grd_cd_6',\
'fin_rsk_ases_grd_cd_7','fin_rsk_ases_grd_cd_8','fin_rsk_ases_grd_cd_9',\
'confirm_rsk_ases_lvl_typ_cd_10','confirm_rsk_ases_lvl_typ_cd_13',\
'confirm_rsk_ases_lvl_typ_cd_8','confirm_rsk_ases_lvl_typ_cd_9',\
'cust_inv_rsk_endu_lvl_cd_9','tot_ast_lvl_cd_0','bk1_cur_year_mon_avg_agn_amt_cd_10',\
'hld_crd_card_grd_cd_60','hld_crd_card_grd_cd_70','perm_crd_lmt_cd_-1'],axis=1,inplace=True)
all_tag.to_csv('train/all_tag.csv',index=False)
all_tag_1.to_csv('b/all_tag_b.csv',index=False)
print(all_tag.shape,all_tag_1.shape)
# Out:
# (39923, 192) (4000, 191)

# %% [markdown]
# ## Merge data

# %%
all_trd = pd.read_csv('train/all_trd.csv')
all_trd_1 = pd.read_csv('b/all_trd_b.csv')
all_tag = pd.read_csv('train/all_tag.csv')
all_tag_1 = pd.read_csv('b/all_tag_b.csv')

# %%
all_dataset = pd.merge(all_trd,all_tag,on='id',how='outer')
test_all_dataset = pd.merge(all_trd_1,all_tag_1,on='id',how='outer')

# %%
_dict={"frs_agn_dt_cnt":4,"cur_debit_cnt":2}
test_subsub_split= pd.DataFrame()
subsub_split= pd.DataFrame()
for i in _dict.keys():
    sub_split = pd.qcut(all_dataset[i],_dict[i],labels=False,duplicates='drop')
    test_sub_split = pd.qcut(test_all_dataset[i],_dict[i],labels=False,duplicates='drop')
    
    subsub_split =pd.concat([subsub_split,sub_split],axis = 1)
    test_subsub_split =pd.concat([test_subsub_split,test_sub_split],axis = 1)
    
subsub_split.columns = [i+"_split" for i in subsub_split.columns]
test_subsub_split.columns = [i+"_split" for i in test_subsub_split.columns]

all_dataset =pd.concat([all_dataset,subsub_split],axis = 1)
test_all_dataset =pd.concat([test_all_dataset,test_subsub_split],axis = 1)

# %%
all_dataset.to_csv('train/all_data.csv',index=False)
test_all_dataset.to_csv('b/all_data_b.csv',index=False)

# %% [markdown]
# ## Missing Value handling

# %%
all_dataset=pd.read_csv('train/all_data.csv')
test_all_dataset=pd.read_csv('b/all_data_b.csv')

# %%
for i in all_dataset.keys()[1:]:
    all_dataset.loc[all_dataset[i]=='\\N',i]=np.nan
    all_dataset[i] = all_dataset[i].astype("float")
for i in test_all_dataset.keys()[1:]:
    test_all_dataset.loc[test_all_dataset[i]=='\\N',i]=np.nan
    test_all_dataset[i] = test_all_dataset[i].astype("float")

# %%
all_dataset['null_value'] = all_dataset.isnull().sum(axis=1)
test_all_dataset['null_value'] = test_all_dataset.isnull().sum(axis=1)

# %%
for i in all_dataset.keys():
    if "\\N" in i and "gdr" not in i and "tot" not in i:
        all_dataset.drop(i,axis=1,inplace=True)
        test_all_dataset.drop(i,axis=1,inplace=True)

# %%
print(all_dataset.shape)
keyset = list(all_dataset.keys()[1:])
keyset.remove("flag")
for i in keyset:
    while test_all_dataset[i].max()<all_dataset[i].max()-max(20,test_all_dataset[i].max()/5):
        print(i,test_all_dataset[i].max(),all_dataset[i].max())
        line_num=np.argmax(all_dataset[i],axis=1)
        all_dataset.drop(line_num,inplace=True)
print(all_dataset.shape)
# Out:
# (39923, 257)
# ('cny_trx_amt', 'sum') 3600835.5800000015 9916500.0
# ('cny_trx_amt', 'sum') 3600835.5800000015 7767903.679999998
# ('cny_trx_amt', 'sum') 3600835.5800000015 5537054.509999998
# ('cny_trx_amt', 'std') 1148006.8415341163 5000000.002014289
# ('cny_trx_amt', 'std') 1148006.8415341163 4601854.9908630615
# ('cny_trx_amt', 'std') 1148006.8415341163 3342169.999098176
# ('cny_trx_amt', 'std') 1148006.8415341163 2852540.1698367707
# ('cny_trx_amt', 'std') 1148006.8415341163 2828427.1250997256
# ('cny_trx_amt', 'std') 1148006.8415341163 2377539.80450011
# ('cny_trx_amt', 'std') 1148006.8415341163 1414213.5852338357
# ('cny_trx_amt', 'min') 30000.0 99294.07
# ('cny_trx_amt', 'min') 30000.0 60000.0
# ('cny_trx_amt', 'min') 30000.0 50000.0
# ('cny_trx_amt', 'min') 30000.0 49000.0
# ('cny_trx_amt', 'min') 30000.0 45000.0
# ('cny_trx_amt', 'min') 30000.0 40300.0
# ('cny_trx_amt', 'mean') 122380.786 149480.26499999998
# ('cny_trx_amt', 'max') 5000000.0 9900000.0
# ('cny_trx_amt', 'max') 5000000.0 7500000.0
# Dat_Flg1_Cd_B 1748.0 5693.0
# Dat_Flg1_Cd_C 679.0 1608.0
# Dat_Flg1_Cd_C 679.0 1357.0
# Dat_Flg1_Cd_C 679.0 1275.0
# Dat_Flg1_Cd_C 679.0 1060.0
# Dat_Flg1_Cd_C 679.0 955.0
# Dat_Flg3_Cd_B 479.0 883.0
# Dat_Flg3_Cd_C 79.0 125.0
# Dat_Flg3_Cd_C 79.0 124.0
# Dat_Flg3_Cd_C 79.0 124.0
# Trx_Cod1_Cd_1 1641.0 2054.0
# Trx_Cod1_Cd_1 1641.0 2051.0
# Trx_Cod1_Cd_2 366.0 670.0
# Trx_Cod1_Cd_2 366.0 652.0
# Trx_Cod1_Cd_2 366.0 616.0
# Trx_Cod1_Cd_2 366.0 536.0
# Trx_Cod1_Cd_2 366.0 498.0
# Trx_Cod1_Cd_2 366.0 473.0
# Trx_Cod1_Cd_2 366.0 463.0
# Trx_Cod1_Cd_2 366.0 450.0
# Trx_Cod2_Cd_101 30.0 61.0
# Trx_Cod2_Cd_102 92.0 176.0
# Trx_Cod2_Cd_107 12.0 58.0
# Trx_Cod2_Cd_108 52.0 105.0
# Trx_Cod2_Cd_109 9.0 51.0
# Trx_Cod2_Cd_112 30.0 119.0
# Trx_Cod2_Cd_112 30.0 94.0
# Trx_Cod2_Cd_112 30.0 88.0
# Trx_Cod2_Cd_112 30.0 81.0
# Trx_Cod2_Cd_112 30.0 65.0
# Trx_Cod2_Cd_112 30.0 60.0
# Trx_Cod2_Cd_112 30.0 57.0
# Trx_Cod2_Cd_112 30.0 55.0
# Trx_Cod2_Cd_112 30.0 55.0
# Trx_Cod2_Cd_112 30.0 51.0
# Trx_Cod2_Cd_113 23.0 82.0
# Trx_Cod2_Cd_113 23.0 77.0
# Trx_Cod2_Cd_113 23.0 75.0
# Trx_Cod2_Cd_113 23.0 68.0
# Trx_Cod2_Cd_113 23.0 63.0
# Trx_Cod2_Cd_113 23.0 60.0
# Trx_Cod2_Cd_114 6.0 61.0
# Trx_Cod2_Cd_114 6.0 31.0
# Trx_Cod2_Cd_116 124.0 166.0
# Trx_Cod2_Cd_117 122.0 173.0
# Trx_Cod2_Cd_118 29.0 51.0
# Trx_Cod2_Cd_118 29.0 50.0
# Trx_Cod2_Cd_123 43.0 64.0
# Trx_Cod2_Cd_126 8.0 140.0
# Trx_Cod2_Cd_126 8.0 124.0
# Trx_Cod2_Cd_126 8.0 36.0
# Trx_Cod2_Cd_127 8.0 39.0
# Trx_Cod2_Cd_128 189.0 479.0
# Trx_Cod2_Cd_128 189.0 374.0
# Trx_Cod2_Cd_128 189.0 357.0
# Trx_Cod2_Cd_128 189.0 315.0
# Trx_Cod2_Cd_130 36.0 89.0
# Trx_Cod2_Cd_134 52.0 243.0
# Trx_Cod2_Cd_134 52.0 236.0
# Trx_Cod2_Cd_134 52.0 135.0
# Trx_Cod2_Cd_134 52.0 94.0
# Trx_Cod2_Cd_134 52.0 93.0
# Trx_Cod2_Cd_134 52.0 75.0
# Trx_Cod2_Cd_135 62.0 90.0
# Trx_Cod2_Cd_135 62.0 89.0
# Trx_Cod2_Cd_136 257.0 1075.0
# Trx_Cod2_Cd_136 257.0 697.0
# Trx_Cod2_Cd_136 257.0 467.0
# Trx_Cod2_Cd_136 257.0 363.0
# Trx_Cod2_Cd_136 257.0 360.0
# Trx_Cod2_Cd_136 257.0 341.0
# Trx_Cod2_Cd_136 257.0 338.0
# Trx_Cod2_Cd_201 9.0 36.0
# Trx_Cod2_Cd_203 13.0 51.0
# Trx_Cod2_Cd_203 13.0 34.0
# Trx_Cod2_Cd_203 13.0 34.0
# Trx_Cod2_Cd_205 12.0 197.0
# Trx_Cod2_Cd_209 81.0 289.0
# Trx_Cod2_Cd_209 81.0 244.0
# Trx_Cod2_Cd_210 9.0 38.0
# Trx_Cod2_Cd_210 9.0 33.0
# Trx_Cod2_Cd_301 46.0 86.0
# Trx_Cod2_Cd_301 46.0 70.0
# Trx_Cod2_Cd_305 39.0 160.0
# Trx_Cod2_Cd_306 17.0 81.0
# Trx_Cod2_Cd_306 17.0 78.0
# Trx_Cod2_Cd_306 17.0 46.0
# Trx_Cod2_Cd_306 17.0 38.0
# Trx_Cod2_Cd_307 43.0 140.0
# Trx_Cod2_Cd_307 43.0 114.0
# Trx_Cod2_Cd_307 43.0 113.0
# Trx_Cod2_Cd_307 43.0 107.0
# Trx_Cod2_Cd_309 56.0 200.0
# Trx_Cod2_Cd_309 56.0 125.0
# Trx_Cod2_Cd_309 56.0 116.0
# Trx_Cod2_Cd_309 56.0 104.0
# Trx_Cod2_Cd_309 56.0 100.0
# Trx_Cod2_Cd_309 56.0 92.0
# Trx_Cod2_Cd_309 56.0 84.0
# Trx_Cod2_Cd_309 56.0 82.0
# Trx_Cod2_Cd_309 56.0 78.0
# Trx_Cod2_Cd_311 4.0 35.0
# Trx_Cod2_Cd_311 4.0 26.0
# job_year 40.0 99.0
# l12mon_buy_fin_mng_whl_tms 63.0 221.0
# l12mon_buy_fin_mng_whl_tms 63.0 135.0
# l12mon_buy_fin_mng_whl_tms 63.0 135.0
# l12mon_buy_fin_mng_whl_tms 63.0 110.0
# l12mon_buy_fin_mng_whl_tms 63.0 101.0
# l12mon_buy_fin_mng_whl_tms 63.0 96.0
# l12mon_buy_fin_mng_whl_tms 63.0 94.0
# l12mon_buy_fin_mng_whl_tms 63.0 85.0
# l12mon_buy_fin_mng_whl_tms 63.0 85.0
# l12mon_buy_fin_mng_whl_tms 63.0 85.0
# l12_mon_fnd_buy_whl_tms 175.0 610.0
# l12_mon_fnd_buy_whl_tms 175.0 288.0
# l12_mon_fnd_buy_whl_tms 175.0 282.0
# ovd_30d_loan_tot_cnt 3.0 28.0
# cur_debit_cnt 75.0 178.0
# cur_debit_cnt 75.0 156.0
# cur_debit_cnt 75.0 138.0
# cur_debit_cnt 75.0 125.0
# cur_debit_cnt 75.0 99.0
# cur_credit_cnt 15.0 173.0
# cur_credit_cnt 15.0 173.0
# (39779, 257)

# %%
all_dataset.to_csv('train/all_data.csv',index=False)
test_all_dataset.to_csv('b/all_data_b.csv',index=False)

# %% [markdown]
# ## Feature Selection

# %%
all_dataset=pd.read_csv('train/all_data.csv')
y = all_dataset['flag'].as_matrix()
X_all = all_dataset.drop(['id','flag'],axis=1,inplace=False)
X=X_all.as_matrix()
X_data, X_test, y_data, y_test = train_test_split(X, y, test_size=0.25)

# %%
model = lgb.LGBMClassifier()
model.fit(X_data, y_data)
predictions = model.predict(X_test)
accuracy = metrics.accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

roc_score = roc_auc_score(y_test, predictions)
print("AUC: %.2f%%" % (roc_score * 100.0))

dict_rank={}
feature_scores = pd.DataFrame(list(X_all.columns), columns=['feature'])
feature_scores['score'] = model.feature_importances_
feature_scores['rank'] = feature_scores['score'].rank(method = 'min', ascending=False)
feature_scores = feature_scores.sort_values('score',ascending=False)
for i in feature_scores.feature:
    dict_rank[i]=dict_rank.get(i,0)+float(feature_scores.loc[(feature_scores['feature'] == i)]['score'])
print(dict_rank)
thresholds = sort(model.feature_importances_)
for thresh in thresholds:
    selection = SelectFromModel(model, threshold=thresh, prefit=True)
    select_X_train = selection.transform(X_data)
    selection_model = lgb.LGBMClassifier()
    selection_model.fit(select_X_train, y_data)
    select_X_test = selection.transform(X_test)
    if (select_X_test.shape[1])<=0:
        break
    predictions = selection_model.predict(select_X_test)
    accuracy = metrics.accuracy_score(y_test, predictions)
    roc_score = roc_auc_score(y_test, predictions)
    print("Thresh=%.3f, n=%d, Accuracy: %.8f%%,AUC: %.8f%%" % (thresh, select_X_train.shape[1], accuracy*100.0,roc_score*100.0))
# Out:
# Accuracy: 81.46%
# AUC: 65.16%
# {'cur_credit_min_opn_dt_cnt': 187.0, "('cny_trx_amt', 'std')": 140.0, 'cur_debit_min_opn_dt_cnt': 116.0, "('cny_trx_amt', 'max')": 105.0, 'Dat_Flg3_Cd_B': 95.0, "('cny_trx_amt', 'sum')": 93.0, "('cny_trx_amt', 'min')": 93.0, 'l1y_crd_card_csm_amt_dlm_cd': 80.0, "('cny_trx_amt', 'mean')": 78.0, 'age': 65.0, 'perm_crd_lmt_cd': 65.0, 'Trx_Cod2_Cd_309': 59.0, 'Trx_Cod1_Cd_3': 59.0, 'job_year': 54.0, 'day_time_0': 49.0, 'frs_agn_dt_cnt': 41.0, 'Trx_Cod2_Cd_308': 40.0, 'Trx_Cod2_Cd_102': 40.0, 'Dat_Flg1_Cd_C': 39.0, 'weekday_1': 39.0, 'Dat_Flg3_Cd_A': 38.0, 'day_time_1': 38.0, 'Trx_Cod2_Cd_136': 38.0, 'pot_ast_lvl_cd': 37.0, 'weekday_0': 37.0, 'Trx_Cod1_Cd_1': 35.0, 'Trx_Cod2_Cd_310': 32.0, 'Trx_Cod2_Cd_134': 32.0, 'Trx_Cod2_Cd_116': 31.0, 'Trx_Cod2_Cd_133': 28.0, 'Trx_Cod2_Cd_111': 28.0, 'Trx_Cod2_Cd_103': 27.0, 'fr_or_sh_ind': 26.0, 'Dat_Flg1_Cd_B': 24.0, 'Trx_Cod2_Cd_213': 23.0, 'hav_car_grp_ind': 23.0, 'Trx_Cod1_Cd_2': 23.0, 'Trx_Cod2_Cd_117': 23.0, 'hld_crd_card_grd_cd': 21.0, 'Trx_Cod2_Cd_104': 21.0, 'Trx_Cod2_Cd_132': 21.0, 'cur_credit_cnt': 21.0, 'his_lng_ovd_day': 20.0, 'dnl_bind_cmb_lif_ind': 20.0, 'Dat_Flg3_Cd_C': 19.0, 'atdd_type': 19.0, 'Trx_Cod2_Cd_208': 19.0, 'Trx_Cod2_Cd_204': 18.0, 'acdm_deg_cd_G': 17.0, 'tot_ast_lvl_cd': 17.0, 'Trx_Cod2_Cd_112': 17.0, 'gdr_cd_M': 17.0, 'Trx_Cod2_Cd_122': 16.0, 'Trx_Cod2_Cd_301': 15.0, 'crd_card_act_ind': 15.0, 'confirm_rsk_ases_lvl_typ_cd': 15.0, 'Trx_Cod2_Cd_118': 15.0, 'Trx_Cod2_Cd_123': 15.0, 'Trx_Cod2_Cd_113': 14.0, 'Trx_Cod2_Cd_128': 13.0, 'l6mon_daim_aum_cd': 13.0, 'l6mon_daim_aum_cd_1': 13.0, 'Trx_Cod2_Cd_131': 13.0, 'cur_debit_cnt': 13.0, 'dnl_mbl_bnk_ind': 12.0, 'perm_crd_lmt_cd_1': 12.0, 'acdm_deg_cd_30': 12.0, 'Trx_Cod2_Cd_129': 12.0, 'Trx_Cod2_Cd_135': 11.0, 'l12_mon_fnd_buy_whl_tms': 11.0, 'cust_inv_rsk_endu_lvl_cd': 11.0, 'fin_rsk_ases_grd_cd': 11.0, 'Trx_Cod2_Cd_130': 11.0, 'cur_debit_crd_lvl_10': 11.0, 'Trx_Cod2_Cd_101': 10.0, 'deg_cd_~': 10.0, 'hld_crd_card_grd_cd_10': 10.0, 'Trx_Cod2_Cd_209': 10.0, 'Trx_Cod2_Cd_302': 9.0, 'l12mon_buy_fin_mng_whl_tms': 9.0, 'mrg_situ_cd_B': 9.0, 'acdm_deg_cd_F': 9.0, 'gdr_cd_F': 9.0, 'edu_deg_cd_K': 9.0, 'Trx_Cod2_Cd_207': 8.0, 'Trx_Cod2_Cd_107': 8.0, 'bk1_cur_year_mon_avg_agn_amt_cd': 7.0, 'Trx_Cod2_Cd_108': 7.0, 'null_value': 7.0, 'perm_crd_lmt_cd_4': 7.0, 'fin_rsk_ases_grd_cd_1': 7.0, 'cust_inv_rsk_endu_lvl_cd_4': 7.0, 'Trx_Cod2_Cd_105': 7.0, 'hld_crd_card_grd_cd_20': 7.0, 'acdm_deg_cd_31': 7.0, 'mrg_situ_cd_A': 6.0, 'Trx_Cod2_Cd_307': 6.0, 'Trx_Cod2_Cd_114': 6.0, 'acdm_deg_cd_Z': 6.0, 'Trx_Cod2_Cd_306': 6.0, 'edu_deg_cd_F': 5.0, 'Trx_Cod2_Cd_125': 5.0, 'l1y_crd_card_csm_amt_dlm_cd_3': 5.0, 'acdm_deg_cd_C': 5.0, 'loan_act_ind': 5.0, 'perm_crd_lmt_cd_2': 4.0, 'perm_crd_lmt_cd_3': 4.0, 'deg_cd_B': 4.0, 'l1y_crd_card_csm_amt_dlm_cd_4': 4.0, 'Trx_Cod2_Cd_205': 4.0, 'perm_crd_lmt_cd_7': 4.0, 'l6mon_daim_aum_cd_7': 4.0, 'l1y_crd_card_csm_amt_dlm_cd_2': 4.0, 'Trx_Cod2_Cd_210': 4.0, 'Trx_Cod2_Cd_110': 4.0, 'cur_debit_crd_lvl': 4.0, 'confirm_rsk_ases_lvl_typ_cd_3': 3.0, 'pl_crd_lmt_cd': 3.0, 'Trx_Cod2_Cd_109': 3.0, 'perm_crd_lmt_cd_5': 3.0, 'tot_ast_lvl_cd_2': 3.0, 'perm_crd_lmt_cd_6': 3.0, 'edu_deg_cd_Z': 3.0, 'mrg_situ_cd_O': 3.0, 'hld_crd_card_grd_cd_55': 3.0, 'ic_ind': 3.0, 'edu_deg_cd_C': 3.0, 'tot_ast_lvl_cd_3': 2.0, 'l6mon_daim_aum_cd_3': 2.0, 'fin_rsk_ases_grd_cd_2': 2.0, 'bk1_cur_year_mon_avg_agn_amt_cd_2': 2.0, 'pot_ast_lvl_cd_4': 2.0, 'fin_rsk_ases_grd_cd_3': 2.0, 'hld_crd_card_grd_cd_23': 2.0, 'Trx_Cod2_Cd_304': 2.0, 'confirm_rsk_ases_lvl_typ_cd_1': 2.0, 'l1y_crd_card_csm_amt_dlm_cd_1': 2.0, 'Trx_Cod2_Cd_127': 2.0, 'confirm_rsk_ases_lvl_typ_cd_2': 2.0, 'cur_credit_min_opn_dt_cnt_split': 2.0, 'pot_ast_lvl_cd_3': 2.0, 'ovd_30d_loan_tot_cnt': 2.0, 'cur_debit_crd_lvl_20': 2.0, 'bk1_cur_year_mon_avg_agn_amt_cd_4': 2.0, 'Trx_Cod2_Cd_202': 2.0, 'vld_rsk_ases_ind': 2.0, 'Trx_Cod2_Cd_106': 2.0, 'edu_deg_cd_B': 2.0, 'deg_cd_A': 2.0, 'pl_crd_lmt_cd_3': 1.0, 'pot_ast_lvl_cd_2': 1.0, 'gdr_cd_\\N': 1.0, 'hld_crd_card_grd_cd_25': 1.0, 'tot_ ...
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=0.000, n=255, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=1.000, n=169, Accuracy: 81.45801911%,AUC: 65.16146696%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=2.000, n=149, Accuracy: 81.22674711%,AUC: 64.76269316%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=3.000, n=127, Accuracy: 81.25691302%,AUC: 64.78222441%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=4.000, n=116, Accuracy: 81.30718954%,AUC: 64.84590577%
# Thresh=5.000, n=105, Accuracy: 81.31724485%,AUC: 64.88354546%
# Thresh=5.000, n=105, Accuracy: 81.31724485%,AUC: 64.88354546%
# Thresh=5.000, n=105, Accuracy: 81.31724485%,AUC: 64.88354546%
# Thresh=5.000, n=105, Accuracy: 81.31724485%,AUC: 64.88354546%
# Thresh=5.000, n=105, Accuracy: 81.31724485%,AUC: 64.88354546%
# Thresh=6.000, n=100, Accuracy: 81.31724485%,AUC: 64.94580401%
# Thresh=6.000, n=100, Accuracy: 81.31724485%,AUC: 64.94580401%
# Thresh=6.000, n=100, Accuracy: 81.31724485%,AUC: 64.94580401%
# Thresh=6.000, n=100, Accuracy: 81.31724485%,AUC: 64.94580401%
# Thresh=6.000, n=100, Accuracy: 81.31724485%,AUC: 64.94580401%
# Thresh=7.000, n=95, Accuracy: 81.08597285%,AUC: 64.57815949%
# Thresh=7.000, n=95, Accuracy: 81.08597285%,AUC: 64.57815949%
# Thresh=7.000, n=95, Accuracy: 81.08597285%,AUC: 64.57815949%
# Thresh=7.000, n=95, Accuracy: 81.08597285%,AUC: 64.57815949%
# Thresh=7.000, n=95, Accuracy: 81.08597285%,AUC: 64.57815949%
# Thresh=7.000, n=95, Accuracy: 81.08597285%,AUC: 64.57815949%
# Thresh=7.000, n=95, Accuracy: 81.08597285%,AUC: 64.57815949%
# Thresh=7.000, n=95, Accuracy: 81.08597285%,AUC: 64.57815949%
# Thresh=7.000, n=95, Accuracy: 81.08597285%,AUC: 64.57815949%
# Thresh=8.000, n=86, Accuracy: 81.11613876%,AUC: 64.62882002%
# Thresh=8.000, n=86, Accuracy: 81.11613876%,AUC: 64.62882002%
# Thresh=9.000, n=84, Accuracy: 81.15635998%,AUC: 64.63929705%
# Thresh=9.000, n=84, Accuracy: 81.15635998%,AUC: 64.63929705%
# Thresh=9.000, n=84, Accuracy: 81.15635998%,AUC: 64.63929705%
# Thresh=9.000, n=84, Accuracy: 81.15635998%,AUC: 64.63929705%
# Thresh=9.000, n=84, Accuracy: 81.15635998%,AUC: 64.63929705%
# Thresh=9.000, n=84, Accuracy: 81.15635998%,AUC: 64.63929705%
# Thresh=10.000, n=78, Accuracy: 81.27702363%,AUC: 64.74855132%
# Thresh=10.000, n=78, Accuracy: 81.27702363%,AUC: 64.74855132%
# Thresh=10.000, n=78, Accuracy: 81.27702363%,AUC: 64.74855132%
# Thresh=10.000, n=78, Accuracy: 81.27702363%,AUC: 64.74855132%
# Thresh=11.000, n=74, Accuracy: 81.27702363%,AUC: 64.81080988%
# Thresh=11.000, n=74, Accuracy: 81.27702363%,AUC: 64.81080988%
# Thresh=11.000, n=74, Accuracy: 81.27702363%,AUC: 64.81080988%
# Thresh=11.000, n=74, Accuracy: 81.27702363%,AUC: 64.81080988%
# Thresh=11.000, n=74, Accuracy: 81.27702363%,AUC: 64.81080988%
# Thresh=11.000, n=74, Accuracy: 81.27702363%,AUC: 64.81080988%
# Thresh=12.000, n=68, Accuracy: 81.29713424%,AUC: 64.87052463%
# Thresh=12.000, n=68, Accuracy: 81.29713424%,AUC: 64.87052463%
# Thresh=12.000, n=68, Accuracy: 81.29713424%,AUC: 64.87052463%
# Thresh=12.000, n=68, Accuracy: 81.29713424%,AUC: 64.87052463%
# Thresh=13.000, n=64, Accuracy: 81.12619407%,AUC: 64.61976580%
# Thresh=13.000, n=64, Accuracy: 81.12619407%,AUC: 64.61976580%
# Thresh=13.000, n=64, Accuracy: 81.12619407%,AUC: 64.61976580%
# Thresh=13.000, n=64, Accuracy: 81.12619407%,AUC: 64.61976580%
# Thresh=13.000, n=64, Accuracy: 81.12619407%,AUC: 64.61976580%
# Thresh=14.000, n=59, Accuracy: 81.17647059%,AUC: 64.76127035%
# Thresh=15.000, n=58, Accuracy: 81.17647059%,AUC: 64.71457643%
# Thresh=15.000, n=58, Accuracy: 81.17647059%,AUC: 64.71457643%
# Thresh=15.000, n=58, Accuracy: 81.17647059%,AUC: 64.71457643%
# Thresh=15.000, n=58, Accuracy: 81.17647059%,AUC: 64.71457643%
# Thresh=15.000, n=58, Accuracy: 81.17647059%,AUC: 64.71457643%
# Thresh=16.000, n=53, Accuracy: 81.03569633%,AUC: 64.53004277%
# Thresh=17.000, n=52, Accuracy: 80.79436903%,AUC: 64.12475855%
# Thresh=17.000, n=52, Accuracy: 80.79436903%,AUC: 64.12475855%
# Thresh=17.000, n=52, Accuracy: 80.79436903%,AUC: 64.12475855%
# Thresh=17.000, n=52, Accuracy: 80.79436903%,AUC: 64.12475855%
# Thresh=18.000, n=48, Accuracy: 80.81447964%,AUC: 64.07552083%
# Thresh=19.000, n=47, Accuracy: 80.75414781%,AUC: 63.70960092%
# Thresh=19.000, n=47, Accuracy: 80.75414781%,AUC: 63.70960092%
# Thresh=19.000, n=47, Accuracy: 80.75414781%,AUC: 63.70960092%
# Thresh=20.000, n=44, Accuracy: 80.63348416%,AUC: 63.55365273%
# Thresh=20.000, n=44, Accuracy: 80.63348416%,AUC: 63.55365273%
# Thresh=21.000, n=42, Accuracy: 80.91503268%,AUC: 63.86046151%
# Thresh=21.000, n=42, Accuracy: 80.91503268%,AUC: 63.86046151%
# Thresh=21.000, n=42, Accuracy: 80.91503268%,AUC: 63.86046151%
# Thresh=21.000, n=42, Accuracy: 80.91503268%,AUC: 63.86046151%
# Thresh=23.000, n=38, Accuracy: 80.67370538%,AUC: 63.56412976%
# Thresh=23.000, n=38, Accuracy: 80.67370538%,AUC: 63.56412976%
# Thresh=23.000, n=38, Accuracy: 80.67370538%,AUC: 63.56412976%
# Thresh=23.000, n=38, Accuracy: 80.67370538%,AUC: 63.56412976%
# Thresh=24.000, n=34, Accuracy: 80.72398190%,AUC: 63.95466853%
# Thresh=26.000, n=33, Accuracy: 80.57315234%,AUC: 63.43676704%
# Thresh=27.000, n=32, Accuracy: 80.69381599%,AUC: 63.53045668%
# Thresh=28.000, n=31, Accuracy: 80.73403720%,AUC: 63.77440328%
# Thresh=28.000, n=31, Accuracy: 80.73403720%,AUC: 63.77440328%
# Thresh=31.000, n=29, Accuracy: 80.94519859%,AUC: 64.02007450%
# Thresh=32.000, n=28, Accuracy: 80.72398190%,AUC: 63.86128070%
# Thresh=32.000, n=28, Accuracy: 80.72398190%,AUC: 63.86128070%
# Thresh=35.000, n=26, Accuracy: 80.82453494%,AUC: 64.05090197%
# Thresh=37.000, n=25, Accuracy: 80.58320764%,AUC: 63.48997137%
# Thresh=37.000, n=25, Accuracy: 80.58320764%,AUC: 63.48997137%
# Thresh=38.000, n=23, Accuracy: 80.62342886%,AUC: 63.59383623%
# Thresh=38.000, n=23, Accuracy: 80.62342886%,AUC: 63.59383623%
# Thresh=38.000, n=23, Accuracy: 80.62342886%,AUC: 63.59383623%
# Thresh=39.000, n=20, Accuracy: 80.56309703%,AUC: 63.69485548%
# Thresh=39.000, n=20, Accuracy: 80.56309703%,AUC: 63.69485548%
# Thresh=40.000, n=18, Accuracy: 80.58320764%,AUC: 63.45884209%
# Thresh=40.000, n=18, Accuracy: 80.58320764%,AUC: 63.45884209%
# Thresh=41.000, n=16, Accuracy: 80.67370538%,AUC: 63.85985789%
# Thresh=49.000, n=15, Accuracy: 80.67370538%,AUC: 63.81316398%
# Thresh=54.000, n=14, Accuracy: 80.55304173%,AUC: 63.78173289%
# Thresh=59.000, n=13, Accuracy: 80.59326295%,AUC: 63.52761107%
# Thresh=59.000, n=13, Accuracy: 80.59326295%,AUC: 63.52761107%
# Thresh=65.000, n=11, Accuracy: 80.04022122%,AUC: 62.08001345%
# Thresh=65.000, n=11, Accuracy: 80.04022122%,AUC: 62.08001345%
# Thresh=78.000, n=9, Accuracy: 80.02011061%,AUC: 62.09812190%
# Thresh=80.000, n=8, Accuracy: 80.02011061%,AUC: 62.09812190%
# Thresh=93.000, n=7, Accuracy: 78.86375063%,AUC: 56.68003242%
# Thresh=93.000, n=7, Accuracy: 78.86375063%,AUC: 56.68003242%
# Thresh=95.000, n=5, Accuracy: 78.77325289%,AUC: 56.10780560%
# Thresh=105.000, n=4, Accuracy: 78.46153846%,AUC: 55.17444467%
# Thresh=116.000, n=3, Accuracy: 77.44595274%,AUC: 51.29501242%
# Thresh=140.000, n=2, Accuracy: 77.45600804%,AUC: 50.97466542%
# Thresh=187.000, n=1, Accuracy: 77.22473605%,AUC: 50.00000000%

# %%
del_list=[]
for i in dict_rank:
    if dict_rank[i]<=1:
        del_list.append(i)

# %%
for i in del_list:
    all_dataset.drop(i,axis=1,inplace=True)

# %%
all_dataset.to_csv('train/all_data.csv',index=False)

# %% [markdown]
# ## GridSearch

# %%
dataset = pd.read_csv('train/all_data.csv')
y_data = dataset['flag'].values
dataset.drop(['flag','id'], axis=1, inplace=True)
X_data = dataset.values

estimators = [50,100,200]
max_depth = [2,4,8,16]
learning_rate = [0.01,0.1,1]
param_grid = dict(max_depth=max_depth, n_estimators=estimators, learning_rate=learning_rate)
model = lgb.LGBMClassifier()
grid_search = GridSearchCV(model, param_grid, verbose=2, cv=10)
grid_result = grid_search.fit(X_data, y_data)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   0.4s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=2, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   0.6s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   0.6s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=100, total=   0.6s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=200, total=   1.3s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=200, total=   1.2s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=200, total=   1.2s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=200, total=   1.2s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=200, total=   1.2s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.01, max_depth=2, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=2, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=4, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=4, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=4, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=4, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=4, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=4, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=4, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=4, n_estimators=50, total=   0.6s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=4, n_estimators=50, total=   0.6s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=4, n_estimators=50, total=   0.6s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, total=   1.7s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, total=   1.4s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, total=   1.5s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, total=   1.5s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, total=   1.4s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, total=   1.4s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, total=   1.4s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, total=   1.4s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, total=   1.5s
# [CV] learning_rate=0.01, max_depth=4, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=4, n_estimators=200, total=   1.5s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=8, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=50 ................
# [CV] . learning_rate=0.01, max_depth=8, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, total=   1.2s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, total=   2.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, total=   2.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, total=   2.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, total=   2.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, total=   2.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, total=   2.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, total=   2.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, total=   2.3s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, total=   2.5s
# [CV] learning_rate=0.01, max_depth=8, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=8, n_estimators=200, total=   2.5s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=50 ...............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=100, total=   1.3s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=100, total=   1.4s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=100 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=100, total=   1.4s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=200 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=200, total=   2.5s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=200 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=200, total=   2.5s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=200 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=200, total=   2.4s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=200 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=200, total=   2.9s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=200 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=200, total=   2.6s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=200 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=200, total=   2.4s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=200 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=200, total=   2.4s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=200 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=200, total=   2.4s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=200 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=200, total=   2.6s
# [CV] learning_rate=0.01, max_depth=16, n_estimators=200 ..............
# [CV]  learning_rate=0.01, max_depth=16, n_estimators=200, total=   2.6s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   0.3s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=0.1, max_depth=2, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=200, total=   1.2s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=200, total=   1.2s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=200, total=   1.2s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=200, total=   1.3s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=4, n_estimators=200, total=   1.1s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=8, n_estimators=50, total=   0.6s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=8, n_estimators=50, total=   0.6s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=8, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=8, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=50 .................
# [CV] .. learning_rate=0.1, max_depth=8, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=100 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=200, total=   1.7s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=200, total=   1.8s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=200, total=   1.7s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=200, total=   1.7s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=200, total=   1.9s
# [CV] learning_rate=0.1, max_depth=8, n_estimators=200 ................
# [CV] . learning_rate=0.1, max_depth=8, n_estimators=200, total=   1.8s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=50 ................
# [CV] . learning_rate=0.1, max_depth=16, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=50 ................
# [CV] . learning_rate=0.1, max_depth=16, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=50 ................
# [CV] . learning_rate=0.1, max_depth=16, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=50 ................
# [CV] . learning_rate=0.1, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=50 ................
# [CV] . learning_rate=0.1, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=50 ................
# [CV] . learning_rate=0.1, max_depth=16, n_estimators=50, total=   0.7s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=50 ................
# [CV] . learning_rate=0.1, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=50 ................
# [CV] . learning_rate=0.1, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=50 ................
# [CV] . learning_rate=0.1, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=50 ................
# [CV] . learning_rate=0.1, max_depth=16, n_estimators=50, total=   0.8s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=100 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=100, total=   1.1s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=200 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=200 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=200 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=200, total=   1.8s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=200 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=200 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=200 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=200 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=200, total=   1.7s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=200 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=200 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=200, total=   2.2s
# [CV] learning_rate=0.1, max_depth=16, n_estimators=200 ...............
# [CV]  learning_rate=0.1, max_depth=16, n_estimators=200, total=   2.1s
# [CV] learning_rate=1, max_depth=2, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=2, n_estimators=50, total=   0.3s
# [CV] learning_rate=1, max_depth=2, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=2, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=2, n_estimators=50, total=   0.3s
# [CV] learning_rate=1, max_depth=2, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=2, n_estimators=50, total=   0.3s
# [CV] learning_rate=1, max_depth=2, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=2, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=2, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=2, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=2, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=2, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=2, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=2, n_estimators=50, total=   0.3s
# [CV] learning_rate=1, max_depth=2, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=1, max_depth=2, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=1, max_depth=2, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=1, max_depth=2, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=1, max_depth=2, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=1, max_depth=2, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=1, max_depth=2, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=1, max_depth=2, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=1, max_depth=2, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=1, max_depth=2, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=100, total=   0.5s
# [CV] learning_rate=1, max_depth=2, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=1, max_depth=2, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=1, max_depth=2, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=1, max_depth=2, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=200, total=   0.7s
# [CV] learning_rate=1, max_depth=2, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=1, max_depth=2, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=1, max_depth=2, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=1, max_depth=2, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=1, max_depth=2, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=1, max_depth=2, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=2, n_estimators=200, total=   0.8s
# [CV] learning_rate=1, max_depth=4, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=4, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=4, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=4, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=4, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=1, max_depth=4, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=4, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=4, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=4, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=4, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=4, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=4, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=4, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=4, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=4, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=4, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=4, n_estimators=50, total=   0.5s
# [CV] learning_rate=1, max_depth=4, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=4, n_estimators=50, total=   0.4s
# [CV] learning_rate=1, max_depth=4, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=100, total=   0.6s
# [CV] learning_rate=1, max_depth=4, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=100, total=   0.6s
# [CV] learning_rate=1, max_depth=4, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=100, total=   0.6s
# [CV] learning_rate=1, max_depth=4, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=1, max_depth=4, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=100, total=   0.6s
# [CV] learning_rate=1, max_depth=4, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=100, total=   0.6s
# [CV] learning_rate=1, max_depth=4, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=100, total=   0.6s
# [CV] learning_rate=1, max_depth=4, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=1, max_depth=4, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=1, max_depth=4, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=100, total=   0.7s
# [CV] learning_rate=1, max_depth=4, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=200, total=   1.1s
# [CV] learning_rate=1, max_depth=4, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=200, total=   1.0s
# [CV] learning_rate=1, max_depth=4, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=200, total=   1.0s
# [CV] learning_rate=1, max_depth=4, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=200, total=   1.0s
# [CV] learning_rate=1, max_depth=4, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=200, total=   1.1s
# [CV] learning_rate=1, max_depth=4, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=200, total=   1.0s
# [CV] learning_rate=1, max_depth=4, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=200, total=   0.9s
# [CV] learning_rate=1, max_depth=4, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=200, total=   1.0s
# [CV] learning_rate=1, max_depth=4, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=200, total=   1.1s
# [CV] learning_rate=1, max_depth=4, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=4, n_estimators=200, total=   1.1s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=8, n_estimators=50, total=   0.5s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=8, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=8, n_estimators=50, total=   0.5s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=8, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=8, n_estimators=50, total=   0.5s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=8, n_estimators=50, total=   0.5s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=8, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=8, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=8, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=8, n_estimators=50 ...................
# [CV] .... learning_rate=1, max_depth=8, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=100, total=   0.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=100, total=   0.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=100, total=   0.9s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=100, total=   0.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=100, total=   0.9s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=100, total=   0.9s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=100, total=   0.9s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=100, total=   0.9s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=100, total=   1.0s
# [CV] learning_rate=1, max_depth=8, n_estimators=100 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=100, total=   0.8s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=200, total=   1.3s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=200, total=   1.5s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=200, total=   1.5s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=200, total=   1.2s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=200, total=   1.5s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=200, total=   1.5s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=200, total=   1.4s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=200, total=   1.5s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=200, total=   1.7s
# [CV] learning_rate=1, max_depth=8, n_estimators=200 ..................
# [CV] ... learning_rate=1, max_depth=8, n_estimators=200, total=   1.3s
# [CV] learning_rate=1, max_depth=16, n_estimators=50 ..................
# [CV] ... learning_rate=1, max_depth=16, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=50 ..................
# [CV] ... learning_rate=1, max_depth=16, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=50 ..................
# [CV] ... learning_rate=1, max_depth=16, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=50 ..................
# [CV] ... learning_rate=1, max_depth=16, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=50 ..................
# [CV] ... learning_rate=1, max_depth=16, n_estimators=50, total=   0.5s
# [CV] learning_rate=1, max_depth=16, n_estimators=50 ..................
# [CV] ... learning_rate=1, max_depth=16, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=50 ..................
# [CV] ... learning_rate=1, max_depth=16, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=50 ..................
# [CV] ... learning_rate=1, max_depth=16, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=50 ..................
# [CV] ... learning_rate=1, max_depth=16, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=50 ..................
# [CV] ... learning_rate=1, max_depth=16, n_estimators=50, total=   0.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=100 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=100, total=   0.9s
# [CV] learning_rate=1, max_depth=16, n_estimators=100 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=100, total=   0.8s
# [CV] learning_rate=1, max_depth=16, n_estimators=100 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=100, total=   0.8s
# [CV] learning_rate=1, max_depth=16, n_estimators=100 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=100, total=   0.8s
# [CV] learning_rate=1, max_depth=16, n_estimators=100 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=100, total=   0.8s
# [CV] learning_rate=1, max_depth=16, n_estimators=100 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=100, total=   0.8s
# [CV] learning_rate=1, max_depth=16, n_estimators=100 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=100, total=   0.8s
# [CV] learning_rate=1, max_depth=16, n_estimators=100 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=100, total=   0.9s
# [CV] learning_rate=1, max_depth=16, n_estimators=100 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=100, total=   1.0s
# [CV] learning_rate=1, max_depth=16, n_estimators=100 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=100, total=   1.0s
# [CV] learning_rate=1, max_depth=16, n_estimators=200 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=200, total=   1.5s
# [CV] learning_rate=1, max_depth=16, n_estimators=200 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=200, total=   1.5s
# [CV] learning_rate=1, max_depth=16, n_estimators=200 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=200, total=   1.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=200 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=200, total=   1.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=200 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=200, total=   1.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=200 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=200, total=   1.5s
# [CV] learning_rate=1, max_depth=16, n_estimators=200 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=200, total=   1.5s
# [CV] learning_rate=1, max_depth=16, n_estimators=200 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=200, total=   1.6s
# [CV] learning_rate=1, max_depth=16, n_estimators=200 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=200, total=   1.7s
# [CV] learning_rate=1, max_depth=16, n_estimators=200 .................
# [CV] .. learning_rate=1, max_depth=16, n_estimators=200, total=   1.6s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed:  5.9min finished
# Best: 0.783604 using {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}
# 0.775434 (0.000113) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50}
# 0.775434 (0.000113) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100}
# 0.781166 (0.004618) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200}
# 0.775434 (0.000113) with: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 50}
# 0.768572 (0.032251) with: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 100}
# 0.762312 (0.087453) with: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200}
# 0.760427 (0.045080) with: {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 50}
# 0.756983 (0.082889) with: {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
# 0.770633 (0.087147) with: {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 200}
# 0.760427 (0.045080) with: {'learning_rate': 0.01, 'max_depth': 16, 'n_estimators': 50}
# 0.757234 (0.082901) with: {'learning_rate': 0.01, 'max_depth': 16, 'n_estimators': 100}
# 0.771060 (0.087584) with: {'learning_rate': 0.01, 'max_depth': 16, 'n_estimators': 200}
# 0.783604 (0.025440) with: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}
# 0.773851 (0.070727) with: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}
# 0.773650 (0.082940) with: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200}
# 0.772769 (0.086983) with: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 50}
# 0.775660 (0.087598) with: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100}
# 0.776490 (0.089558) with: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200}
# 0.776842 (0.089266) with: {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 50}
# 0.777143 (0.089939) with: {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 100}
# 0.777445 (0.089774) with: {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 200}
# 0.776263 (0.089412) with: {'learning_rate': 0.1, 'max_depth': 16, 'n_estimators': 50}
# 0.777520 (0.089971) with: {'learning_rate': 0.1, 'max_depth': 16, 'n_estimators': 100}
# 0.777219 (0.090371) with: {'learning_rate': 0.1, 'max_depth': 16, 'n_estimators': 200}
# 0.773348 (0.086413) with: {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 50}
# 0.771663 (0.088645) with: {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 100}
# 0.766937 (0.085214) with: {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 200}
# 0.756354 (0.085537) with: {'learning_rate': 1, 'max_depth': 4, 'n_estimators': 50}
# 0.750220 (0.084895) with: {'learning_rate': 1, 'max_depth': 4, 'n_estimators': 100}
# 0.738631 (0.082100) with: {'learning_rate': 1, 'max_depth': 4, 'n_estimators': 200}
# 0.731264 (0.077853) with: {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 50}
# 0.723748 (0.074342) with: {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 100}
# 0.718141 (0.080735) with: {'learning_rate': 1, 'max_depth': 8, 'n_estimators': 200}
# 0.731064 (0.080443) with: {'learning_rate': 1, 'max_depth': 16, 'n_estimators': 50}
# 0.723270 (0.078173) with: {'learning_rate': 1, 'max_depth': 16, 'n_estimators': 100}
# 0.717112 (0.075805) with: {'learning_rate': 1, 'max_depth': 16, 'n_estimators': 200}

# %%
#'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50

# %% [markdown]
# ## Run test set

# %%
all_dataset = pd.read_csv('train/all_data.csv')
test_all_dataset = pd.read_csv('b/all_data_b.csv')

# %%
key_set = list(all_dataset.keys())
key_set.remove('flag')

# %%
test_all_dataset = test_all_dataset[key_set]
test_all_dataset.to_csv('b/all_data_b.csv',index=False)

# %%
print(all_dataset.shape,test_all_dataset.shape)
# Out:
# (39779, 151) (4000, 150)

# %%
def feature_selection():
    data_set = pd.read_csv('train/all_data.csv')
    kf = KFold(n_splits=8,shuffle=True)
    models = [0] * kf.get_n_splits()

    y = data_set['flag']
    data_set.drop(['flag','id'], axis=1, inplace=True)
    X = data_set.fillna(0)

    X_data = X.values
    y_data = y.values
    
    test_set=pd.read_csv('b/all_data_b.csv')
    test_set.drop(['id'], axis=1, inplace=True)
    X_test = test_set.values
    
    
    roc_scores = []
    accuracy = 0
    preds_store = np.zeros((X_test.shape[0]))
    preds_data = np.zeros((X_test.shape[0]))
    i=0
    for train_index, val_index in kf.split(X_data,y_data):
        X_train, X_val = X_data[train_index], X_data[val_index]
        y_train, y_val = y_data[train_index], y_data[val_index]
        eval_set = [(X_train, y_train), (X_val, y_val)]
        models[i] = sklearn.ensemble.GradientBoostingClassifier(learning_rate= 0.1,
                          max_depth=16,
                          n_estimators=150)
        models[i].fit(X_train, y_train)
        score = models[i].predict_proba(X_val)[:, 1]
        roc = roc_auc_score(y_val, score)
        roc_scores.append(roc)
    
        preds_data = models[i].predict_proba(X_test)[:,1]
        preds_store = preds_store+preds_data
        i+=1
    print(i)
    preds_store=preds_store/8
    print("mean_roc_score: %f"%(np.mean(roc_scores)))
    return (preds_store)

# %%
data_set = pd.read_csv('b/all_data_b.csv')
dict_rank={}
test_preds = pd.DataFrame({"id": data_set['id']})
test_preds['pred'] = feature_selection()
test_preds.to_csv('b/answer.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-2e9dbf7cab57> in <module>
#       2 dict_rank={}
#       3 test_preds = pd.DataFrame({"id": data_set['id']})
# ----> 4 test_preds['pred'] = feature_selection()
#       5 test_preds.to_csv('b/answer.csv',index=False)
#
# <ipython-input-17-ac077e10b6c9> in feature_selection()
#      33         roc_scores.append(roc)
#      34
# ---> 35         preds_data = models[i].predict_proba(X_test)[:,1]
#      36         preds_store = preds_store+preds_data
#      37         i+=1
#
# D:\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in predict_proba(self, X)
#    2212             classes corresponds to that in the attribute :term:`classes_`.
#    2213         """
# -> 2214         raw_predictions = self.decision_function(X)
#    2215         try:
#    2216             return self.loss_._raw_prediction_to_proba(raw_predictions)
#
# D:\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in decision_function(self, X)
#    2118             array of shape [n_samples].
#    2119         """
# -> 2120         X = check_array(X, dtype=DTYPE, order="C", accept_sparse='csr')
#    2121         raw_predictions = self._raw_predict(X)
#    2122         if raw_predictions.shape[1] == 1:
#
# D:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# D:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
def write_into(path):
    a = open(path, "r")
    data_x= pd.read_csv(filepath_or_buffer = path, sep = ',')["id"].values
    data_y= pd.read_csv(filepath_or_buffer = path, sep = ',')["pred"].values
    f=open('b/answer.txt', 'a')
    for i in range(0,len(a.readlines())-1):
        f.write(str(data_x[i]))
        f.write('\t')
        f.write(str(float(data_y[i])-0.004))
        f.write('\n')
    f.close()

# %%
write_into('b/answer.csv')
